# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
ratings = pd.read_csv('/Users/yugjain/Documents/Machine_learning/Movies/datasets/rating.csv')
movies=pd.read_csv('/Users/yugjain/Documents/Machine_learning/Movies/datasets/movie.csv')
